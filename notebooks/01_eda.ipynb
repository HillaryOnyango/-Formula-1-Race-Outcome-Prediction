# %% [markdown]
# # Formula 1 Race Prediction EDA
#
# Use this notebook to explore the cleaned dataset and feature table.

# %%
import pandas as pd

df = pd.read_parquet('../data/processed/model_table.parquet')
df.head()
